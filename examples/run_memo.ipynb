# %%
# !git clone https://github.com/production-ml-lab/test-time-adaptation.git
# Out:
# Cloning into 'test-time-adaptation'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --list
# Out:
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# filter.lfs.clean=git-lfs clean -- %f

# %%
# !git clone https://HwangJohn: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@github.com/production-ml-lab/test-time-adaptation.git
# Out:
# Cloning into 'test-time-adaptation'...
# remote: Enumerating objects: 239, done.
# remote: Counting objects: 100% (239/239), done.
# remote: Compressing objects: 100% (159/159), done.
# remote: Total 239 (delta 110), reused 185 (delta 67), pack-reused 0 (from 0)
# Receiving objects: 100% (239/239), 1.36 MiB | 8.49 MiB/s, done.
# Resolving deltas: 100% (110/110), done.

# %%
# !pwd
# Out:
# /content

# %%
import os
os.chdir("/content/test-time-adaptation")

# %%
# !pip install uv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 94.8 MB/s eta 0:00:00
# ...

# %%
# !uv venv .venv --python=python3.11.11
# Out:
# Using CPython 3.11.11 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate

# %%
# %%bash
# source .venv/bin/activate
# pip install -e .
# pip uninstall -y robustbench
# pip install git+https://github.com/RobustBench/robustbench.git
# Out:
# Obtaining file:///content/test-time-adaptation
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached autoattack-0.1-py3-none-any.whl
# ...
#   Building editable for tta (pyproject.toml): started
#   Building editable for tta (pyproject.toml): finished with status 'done'
#   Created wheel for tta: filename=tta-0.1.0-0.editable-py3-none-any.whl size=7152 sha256=e480fde9df957defe018cbc8ecdd0e53232d564dd9205176d92485a1678a6cac
# ...

# %%
# %%bash
# # source .venv/bin/activate
# git checkout dev/memo
# python run_tta.py --config tta/config/cifar10c/memo.yaml
# Out:
# Your branch is up to date with 'origin/dev/memo'.
# Starting download from https://zenodo.org/api/records/2535967/files/CIFAR-10-C.tar/content
# Download finished, extracting...
# Downloaded and extracted.
# ...
