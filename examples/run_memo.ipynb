# %%
from google.colab import userdata
GITHUB_ID = userdata.get('GITHUB_ID')
GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')
# github id와 token을 입력하시면 됩니다.
# !git clone https://GITHUB_ID:GITHUB_TOKEN@github.com/production-ml-lab/test-time-adaptation.git
# Out:
# Cloning into 'test-time-adaptation'...
# remote: Enumerating objects: 279, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 279 (delta 49), reused 40 (delta 29), pack-reused 185 (from 1)
# Receiving objects: 100% (279/279), 1.39 MiB | 16.34 MiB/s, done.
# Resolving deltas: 100% (120/120), done.

# %%
import os
os.chdir("/content/test-time-adaptation")

# %%
# !pip install uv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.2/16.2 MB 52.4 MB/s eta 0:00:00
# ...

# %%
# !uv venv .venv --python=python3.11.11
# Out:
# Using CPython 3.11.11 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate

# %%
# uv로 패키지 설치 시 robustbench관련 오류 발생하여 수동 설치
# %%bash
source .venv/bin/activate
pip install yacs numpy==1.26.4 tabulate>=0.9.0 torch==2.5.1 torchvision==0.20.1 yacs>=0.1.8
pip install git+https://github.com/RobustBench/robustbench.git
# Out:
# ...
#   Cloning https://github.com/RobustBench/robustbench.git to /tmp/pip-req-build-p99zbr10
#   Resolved https://github.com/RobustBench/robustbench.git to commit 9cd54ee2c0197f024124f836e7b10c883b143adf
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached autoattack-0.1-py3-none-any.whl
# ...
#   Running command git clone --filter=blob:none --quiet https://github.com/RobustBench/robustbench.git /tmp/pip-req-build-p99zbr10

# %%
#memo 실행
# %%bash
source .venv/bin/activate
git checkout dev/engine
python run_tta.py --config config/cifar10c/memo.yaml
# Out:
# Your branch is up to date with 'origin/dev/engine'.
# Starting download from https://zenodo.org/api/records/2535967/files/CIFAR-10-C.tar/content
# Download finished, extracting...
# Downloaded and extracted.
# ...
